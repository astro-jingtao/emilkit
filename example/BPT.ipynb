# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from emilkit.BPT import NIIBPT, SIIBPT, OIBPT

# %%
NIIBPT().draw()
# Out:
# <Axes: xlabel='$\\log$ [NII] 6584 / H$\\alpha$', ylabel='$\\log$ [OIII] 5007 / H$\\beta$'>

# %%
SIIBPT().draw()

# %%
OIBPT().draw()

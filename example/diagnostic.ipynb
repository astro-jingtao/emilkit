# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from emilkit.diagnostic import NIIBPT, SIIBPT, OIBPT, SMB

# %%
NIIBPT().draw()
# Out:
# <Axes: xlabel='$\\log$ [NII] 6583 / H$\\alpha$', ylabel='$\\log$ [OIII] 5007 / H$\\beta$'>

# %%
SIIBPT().draw()

# %%
OIBPT().draw()

# %%
SMB().draw()

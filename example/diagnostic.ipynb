# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

from emilkit.diagnostic import NIIBPT, SIIBPT, OIBPT, SMB

# %%
x = np.random.normal(-0.4, size=100)
y = np.random.normal(0, size=100)

NIIBPT().draw()

_cls = NIIBPT().judge(x, y)

plt.scatter(x, y, c=_cls, cmap='tab20')
plt.colorbar()

# %%
SIIBPT().draw()

# %%
OIBPT().draw()

# %%
SMB().draw()
